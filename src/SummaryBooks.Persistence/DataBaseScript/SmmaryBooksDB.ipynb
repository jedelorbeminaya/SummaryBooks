-- %% [markdown]
-- # [SummaryBooksDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [SummaryBooksDB]    Script Date: 10/4/2024 10:26:31 p. m. ******/
CREATE DATABASE [SummaryBooksDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'SummaryBooksDB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS03\MSSQL\DATA\SummaryBooksDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'SummaryBooksDB_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS03\MSSQL\DATA\SummaryBooksDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [SummaryBooksDB] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [SummaryBooksDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [SummaryBooksDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [SummaryBooksDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [SummaryBooksDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [SummaryBooksDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [SummaryBooksDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [SummaryBooksDB] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [SummaryBooksDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [SummaryBooksDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [SummaryBooksDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [SummaryBooksDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [SummaryBooksDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [SummaryBooksDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [SummaryBooksDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [SummaryBooksDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [SummaryBooksDB] SET  ENABLE_BROKER 
GO
ALTER DATABASE [SummaryBooksDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [SummaryBooksDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [SummaryBooksDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [SummaryBooksDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [SummaryBooksDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [SummaryBooksDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [SummaryBooksDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [SummaryBooksDB] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [SummaryBooksDB] SET  MULTI_USER 
GO
ALTER DATABASE [SummaryBooksDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [SummaryBooksDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [SummaryBooksDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [SummaryBooksDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [SummaryBooksDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [SummaryBooksDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [SummaryBooksDB] SET QUERY_STORE = ON
GO
ALTER DATABASE [SummaryBooksDB] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
USE [SummaryBooksDB]
GO

-- %%
/****** Object:  Table [dbo].[__EFMigrationsHistory]    Script Date: 10/4/2024 10:26:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[__EFMigrationsHistory](
	[MigrationId] [nvarchar](150) NOT NULL,
	[ProductVersion] [nvarchar](32) NOT NULL,
 CONSTRAINT [PK___EFMigrationsHistory] PRIMARY KEY CLUSTERED 
(
	[MigrationId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Summaries]

-- %%
/****** Object:  Table [dbo].[Summaries]    Script Date: 10/4/2024 10:26:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Summaries](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[title] [varchar](200) NULL,
	[description] [text] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [SummaryBooksDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [SummaryBooksDB] SET  READ_WRITE 
GO
